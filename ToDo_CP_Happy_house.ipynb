# %% [markdown]
# <a href="https://colab.research.google.com/github/YousraFarhani/Happy_House_Deep_Learning/blob/main/ToDo_CP_Happy_house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from keras.layers import Conv2D, Dense, MaxPool2D, Flatten, Dropout, Activation

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential()

#Conv layer 1
model.add(Conv2D(filters=20, kernel_size = (3, 3), padding = "same", strides=(1,2), input_shape=(64, 64, 3),activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

#Conv layer 2
model.add(Conv2D(filters=20, kernel_size = (3, 3), padding = "same", strides=(1,2),activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

#Flatten layer
model.add(Flatten())

#Fully connected layers
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))

#output layer
model.add(Dense(units = 1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 64, 32, 20)        560
#
#  max_pooling2d (MaxPooling2D  (None, 32, 16, 20)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 32, 8, 20)         3620
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 4, 20)        0
#  2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 64)                81984
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 90,389
# Trainable params: 90,389
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(optimizer=RMSprop(), loss='binary_crossentropy', metrics=["accuracy"])

# %%
history_model = model.fit(X_train,Y_train,batch_size=10,epochs=50,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 2s 24ms/step - loss: 0.6920 - accuracy: 0.5562 - val_loss: 0.6857 - val_accuracy: 0.4500
# Epoch 2/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.6529 - accuracy: 0.6250 - val_loss: 0.5756 - val_accuracy: 0.7417
# Epoch 3/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.5007 - accuracy: 0.7750 - val_loss: 0.4514 - val_accuracy: 0.7583
# Epoch 4/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.3740 - accuracy: 0.8333 - val_loss: 0.5500 - val_accuracy: 0.6917
# Epoch 5/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.2959 - accuracy: 0.8792 - val_loss: 0.2039 - val_accuracy: 0.9167
# Epoch 6/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.2618 - accuracy: 0.9062 - val_loss: 0.1686 - val_accuracy: 0.9583
# Epoch 7/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.2074 - accuracy: 0.9167 - val_loss: 0.1914 - val_accuracy: 0.9167
# Epoch 8/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.1784 - accuracy: 0.9354 - val_loss: 0.1284 - val_accuracy: 0.9667
# Epoch 9/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.1497 - accuracy: 0.9396 - val_loss: 0.0706 - val_accuracy: 0.9750
# Epoch 10/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.1131 - accuracy: 0.9604 - val_loss: 0.2768 - val_accuracy: 0.9000
# Epoch 11/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.1125 - accuracy: 0.9583 - val_loss: 0.0770 - val_accuracy: 0.9917
# Epoch 12/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.1013 - accuracy: 0.9646 - val_loss: 0.1195 - val_accuracy: 0.9667
# Epoch 13/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.1075 - accuracy: 0.9583 - val_loss: 0.0422 - val_accuracy: 0.9833
# Epoch 14/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0783 - accuracy: 0.9708 - val_loss: 0.3686 - val_accuracy: 0.8917
# Epoch 15/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0832 - accuracy: 0.9812 - val_loss: 0.1364 - val_accuracy: 0.9250
# Epoch 16/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0777 - accuracy: 0.9771 - val_loss: 0.0534 - val_accuracy: 0.9750
# Epoch 17/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0691 - accuracy: 0.9771 - val_loss: 0.0480 - val_accuracy: 0.9833
# Epoch 18/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0551 - accuracy: 0.9854 - val_loss: 0.1590 - val_accuracy: 0.9500
# Epoch 19/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0855 - accuracy: 0.9688 - val_loss: 0.0502 - val_accuracy: 0.9833
# Epoch 20/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0510 - accuracy: 0.9833 - val_loss: 0.0431 - val_accuracy: 0.9833
# Epoch 21/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0544 - accuracy: 0.9792 - val_loss: 0.0215 - val_accuracy: 0.9917
# Epoch 22/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0598 - accuracy: 0.9854 - val_loss: 0.0316 - val_accuracy: 0.9917
# Epoch 23/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0260 - accuracy: 0.9937 - val_loss: 0.0620 - val_accuracy: 0.9833
# Epoch 24/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0383 - accuracy: 0.9854 - val_loss: 0.0531 - val_accuracy: 0.9750
# Epoch 25/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0295 - accuracy: 0.9958 - val_loss: 0.0178 - val_accuracy: 0.9917
# Epoch 26/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0336 - accuracy: 0.9854 - val_loss: 0.0192 - val_accuracy: 0.9917
# Epoch 27/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0542 - accuracy: 0.9812 - val_loss: 0.0538 - val_accuracy: 0.9750
# Epoch 28/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0883 - accuracy: 0.9750 - val_loss: 0.0461 - val_accuracy: 0.9833
# Epoch 29/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0250 - accuracy: 0.9937 - val_loss: 0.1335 - val_accuracy: 0.9250
# Epoch 30/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0437 - accuracy: 0.9854 - val_loss: 0.0347 - val_accuracy: 0.9917
# Epoch 31/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0253 - accuracy: 0.9958 - val_loss: 0.1236 - val_accuracy: 0.9750
# Epoch 32/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.0326 - val_accuracy: 0.9833
# Epoch 33/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0344 - accuracy: 0.9958 - val_loss: 0.0545 - val_accuracy: 0.9750
# Epoch 34/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0334 - accuracy: 0.9937 - val_loss: 0.0262 - val_accuracy: 0.9917
# Epoch 35/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0350 - accuracy: 0.9875 - val_loss: 0.0550 - val_accuracy: 0.9833
# Epoch 36/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0462 - accuracy: 0.9937 - val_loss: 0.0715 - val_accuracy: 0.9583
# Epoch 37/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0349 - accuracy: 0.9875 - val_loss: 0.0520 - val_accuracy: 0.9667
# Epoch 38/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0115 - accuracy: 0.9937 - val_loss: 0.0691 - val_accuracy: 0.9667
# Epoch 39/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0303 - accuracy: 0.9937 - val_loss: 0.0692 - val_accuracy: 0.9667
# Epoch 40/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.2720 - val_accuracy: 0.9417
# Epoch 41/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0281 - accuracy: 0.9917 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 42/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0177 - accuracy: 0.9958 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 43/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 44/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0176 - accuracy: 0.9917 - val_loss: 0.0655 - val_accuracy: 0.9750
# Epoch 45/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0335 - accuracy: 0.9917 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 46/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.1863 - val_accuracy: 0.9250
# Epoch 47/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0554 - accuracy: 0.9896 - val_loss: 0.0673 - val_accuracy: 0.9667
# Epoch 48/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0344 - accuracy: 0.9833 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 49/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0150 - accuracy: 0.9958 - val_loss: 0.0866 - val_accuracy: 0.9750
# Epoch 50/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0187 - accuracy: 0.9917 - val_loss: 0.0602 - val_accuracy: 0.9667

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history_model.history['val_accuracy']
train_loss = history_model.history['val_loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %% [markdown]
# Evaluate Test set

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.9666666388511658

# %%
pred = model.predict(X_test)
predictions = [float(np.round(x)) for x in pred]
# Out:
# 5/5 [==============================] - 0s 17ms/step

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import f1_score, classification_report,confusion_matrix, ConfusionMatrixDisplay
def conf_matrix(y_test, y_pred, model):
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    fig, ax = plt.subplots(figsize=(15,12))
    disp.plot(ax=ax)
    plt.show()
conf_matrix(Y_test, predictions, model)

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="sgd", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adadelta", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adagrad", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adamax", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Nadam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Ftrl", loss='binary_crossentropy', metrics=["accuracy"])

# %%
text_labels = ["Sad", "Happy"]

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 150)
    plt.imshow(X_test_orig[img_index], cmap=plt.cm.gray)
    actual_label  = Y_test[img_index][0]
    predicted_label = int(predictions[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
